# %% [markdown]
# # Pythonic Finite Element Method
#
# - Solve PDE equation using python interface
#
# - First 2D only, with scriptable geometry definition and meshing
#
# - Easy implementation of the physics and boundary conditions
#
#
# ## Framework
#
# ### Tested
#
# - [Fenics](https://fenicsproject.org/): [github](https://github.com/FEniCS/dolfin)
#     - documentation mixed between versions
#     - no variable mesh size constrain
# - NGsolve + Netgen: [github](https://github.com/NGSolve/ngsolve)
#     - no inline ploting solution (matplotlib)...
#
# - Firedrake
#     - no mesher:
#         Triangle but the import seems not to work
#         Gmesh...
#
# ### Other with Python API
#
# - [getfem](http://getfem.org/python/index.html):
#     - no mesher
#
# - http://www.agros2d.org/features/
#
# - https://firedrakeproject.org/documentation.html [github](https://github.com/firedrakeproject/firedrake)
#
# Presentation https://fenicsproject.org/pub/presentations/fenics14-paris/FEniCS14FlorianRathgeber.pdf
#
# # refs
# - Agros2D, CalculiX, Code Aster, DUNE, FEBio, FEniCS, FreeFem++, GetFEM++, Scilab., Hermes Project Modular C/C++ library, jFEM 2D/3D, IMTEK, Mathematica Supplement, MoFEM JosePH MoFEM, MOOSE, OOFEM, OpenFOAM, OpenSees, Z88/Z88Aurora [see Researchgate answer](https://www.researchgate.net/post/Can_anyone_provide_a_list_of_open_source_FEM_software_where_I_can_edit_code)
#
# - https://github.com/kostyfisik/FEA-compare/blob/master/README.org
#
#
#
# ## Mesher
#
# see [PyMesh](https://pymesh.readthedocs.io/en/latest/): *PyMesh is ... focused on geometry processing. It provides a set of common mesh processing functionalities and interfaces with ... open source packages ...*
#
#
# #### Triangle by  Jonathan Richard Shewchuk
# https://www.cs.cmu.edu/~quake/triangle.html
#
#
#
# * no geometry building tool... but easy to write [one](./geom4triangle.ipynb)
# * only 2D
#
#
# ##### Python API
#
# * https://rufat.be/triangle/API.html
#     * but no export option... :/
#
# * [meshpy](https://mathema.tician.de/software/meshpy/) [doc](https://documen.tician.de/meshpy/)
#     * no installation package, but ok after installing `pybind11`
#
# #### Gmesh
#
# - Python library: [pygmsh](https://pygmsh.readthedocs.io/en/latest/)... usefull?
# - Python API: [doc](http://gmsh.info/doc/texinfo/gmsh.html#Gmsh-API), [source](https://gitlab.onelab.info/gmsh/gmsh/blob/master/api/gmsh.py), [README](https://gitlab.onelab.info/gmsh/gmsh/blob/master/demos/api/README.txt), [pip install gmsh-sdk](https://pypi.org/project/gmsh-sdk/)
#
# #### Autres
#
# Netgen, [meshio](https://github.com/nschloe/meshio)...
